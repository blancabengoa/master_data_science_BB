# %% [markdown]
# # Datos reservas hidroeléctricas
#
# Los datos del estado de las reservas hidroeléctricas los publica mensualmente ree en el apdo. de  *EstadísticasSeries estadísticas nacionales*.
#
# https://www.ree.es/es/estadisticas-del-sistema-electrico-espanol/series-estadisticas/series-estadisticas-nacionales
#
# Del enlace expuesto me extraigo los datos de Producible hidráulico y reservas hidroeléctricas para, en este notebook, leerlos y ponerlos en un formato adecuado que me sirva después para unificar todos los datos.

# %% [markdown]
# ## 1. Importamos librerías necesarias

# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# ## 2. Lectura y testeo de datos

# %%
df=pd.read_csv('../data/EMBALSES.csv',sep=';')
df.head(5)
# Out:
#       MES  Reservas embalses anuales (GWh)  \
# 0  ene-15                            5.595
# 1  feb-15                            5.942
# 2  mar-15                            6.160
# 3  abr-15                            6.303
# 4  may-15                            6.224
#
#    Reservas embalses hiperanuales (GWh)
# 0                                 6.293
# 1                                 6.679
# 2                                 6.758
# 3                                 6.901
# 4                                 6.663

# %%
df.dtypes
# Out:
# MES                                      object
# Reservas embalses anuales (GWh)         float64
# Reservas embalses hiperanuales (GWh)    float64
# dtype: object

# %% [markdown]
# Los meses no me los reconoce con el formato %b al estar en español, así que los convierto a código numérico a través de un diccionario

# %%
calendar=list(['ene','feb','mar','abr','may','jun','jul','ago','sep','oct','nov','dic'])
dict={}
for m in range(12):
    dict[calendar[m]]=m+1
    
aux=df['MES'].str.split('-') 
fecha=[]
for i in aux:
    mes=dict[i[0]]
    ano=i[1]
    fecha.append(str(mes)+'-'+str(ano))
    #fecha.append(pd.to_datetime(datetime.datetime.strptime(str(mes)+'-'+i[1],'%m-%y')))
    
df['mes_ano']=pd.Series(fecha)

df.head()
# Out:
#       MES  Reservas embalses anuales (GWh)  \
# 0  ene-15                            5.595
# 1  feb-15                            5.942
# 2  mar-15                            6.160
# 3  abr-15                            6.303
# 4  may-15                            6.224
#
#    Reservas embalses hiperanuales (GWh) mes_ano
# 0                                 6.293    1-15
# 1                                 6.679    2-15
# 2                                 6.758    3-15
# 3                                 6.901    4-15
# 4                                 6.663    5-15

# %% [markdown]
# Los datos extraídos son mensuales, todos mis datos son horarios. De momento convierto todos los datos a diarios y, cuando unifique todos en un único archivo, los pasaré a horarios.
#
# Para pasarlos a horarios simplemente pondré el mismo valor todos los días del mes ya que no tendré el dato del estado del embalse para el día siguiente con mayor precisión en la vida real.

# %%
embalses=pd.DataFrame(pd.date_range(start='2015-10-01',end='2018-09-30'),columns=['datetime'])
embalses.head()
# Out:
#     datetime
# 0 2015-10-01
# 1 2015-10-02
# 2 2015-10-03
# 3 2015-10-04
# 4 2015-10-05

# %%
#me creo una columna aux mes_ano igual que la anterior para unir después ambos dataframes por esta columna
embalses['mes_ano']=[str(x.month) + '-' + str(x.year)[-2:] for x in embalses['datetime']] 
embalses.head()
# Out:
#     datetime mes_ano
# 0 2015-10-01   10-15
# 1 2015-10-02   10-15
# 2 2015-10-03   10-15
# 3 2015-10-04   10-15
# 4 2015-10-05   10-15

# %%
embalses_dia=embalses.merge(df,on='mes_ano')
embalses_dia.head(32)
# Out:
#      datetime mes_ano     MES  Reservas embalses anuales (GWh)  \
# 0  2015-10-01   10-15  oct-15                            3.714
# 1  2015-10-02   10-15  oct-15                            3.714
# 2  2015-10-03   10-15  oct-15                            3.714
# 3  2015-10-04   10-15  oct-15                            3.714
# 4  2015-10-05   10-15  oct-15                            3.714
# 5  2015-10-06   10-15  oct-15                            3.714
# 6  2015-10-07   10-15  oct-15                            3.714
# 7  2015-10-08   10-15  oct-15                            3.714
# 8  2015-10-09   10-15  oct-15                            3.714
# 9  2015-10-10   10-15  oct-15                            3.714
# 10 2015-10-11   10-15  oct-15                            3.714
# 11 2015-10-12   10-15  oct-15                            3.714
# 12 2015-10-13   10-15  oct-15                            3.714
# 13 2015-10-14   10-15  oct-15                            3.714
# 14 2015-10-15   10-15  oct-15                            3.714
# 15 2015-10-16   10-15  oct-15                            3.714
# 16 2015-10-17   10-15  oct-15                            3.714
# 17 2015-10-18   10-15  oct-15                            3.714
# 18 2015-10-19   10-15  oct-15                            3.714
# 19 2015-10-20   10-15  oct-15                            3.714
# 20 2015-10-21   10-15  oct-15                            3.714
# 21 2015-10-22   10-15  oct-15                            3.714
# 22 2015-10-23   10-15  oct-15                            3.714
# 23 2015-10-24   10-15  oct-15                            3.714
# 24 2015-10-25   10-15  oct-15                            3.714
# 25 2015-10-26   10-15  oct-15                            3.714
# 26 2015-10-27   10-15  oct-15                            3.714
# 27 2015-10-28   10-15  oct-15                            3.714
# 28 2015-10-29   10-15  oct-15                            3.714
# 29 2015-10-30   10-15  oct-15                            3.714
# 30 2015-10-31   10-15  oct-15                            3.714
# 31 2015-11-01   11-15  nov-15                            3.936
#
#     Reservas embalses hiperanuales (GWh)
# 0                                  4.909
# 1                                  4.909
# 2                                  4.909
# 3                                  4.909
# 4                                  4.909
# 5                                  4.909
# 6                                  4.909
# 7                                  4.909
# 8                                  4.909
# 9                                  4.909
# 10                                 4.909
# 11                                 4.909
# 12                                 4.909
# 13                                 4.909
# 14                                 4.909
# 15                                 4.909
# 16                                 4.909
# 17                                 4.909
# 18                                 4.909
# 19                                 4.909
# 20                                 4.909
# 21                                 4.909
# 22                                 4.909
# 23                                 4.909
# 24                                 4.909
# 25                                 4.909
# 26                                 4.909
# 27                                 4.909
# 28                                 4.909
# 29                                 4.909
# 30                                 4.909
# 31                                 4.809

# %%
embalses_dia.shape  #No NaN
# Out:
# (1096, 5)

# %%
embalses_dia['mes_ano'].count()
# Out:
# 1096

# %% [markdown]
# ## 3. Salvar datos

# %%
embalses_dia.to_csv('../data/embalses_dia.csv',sep=';',index= False)
